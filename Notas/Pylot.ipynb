# %% [markdown]
# # Matplot

# %%
#Importando Librerias
import matplotlib.pyplot as plt
import numpy as np

# %%
#Definiendo Variables
x = np.linspace(0,5,11)
y = x**2

# %% [markdown]
# ## Empezando a manipular la librería

# %%
# Grafico de relacion 2 variables
plt.plot(x,y,'bx')
plt.show()

# %%
plt.plot(x,y,'rs-')
plt.show()

# %%
plt.plot(x,y,'yD:')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Histograma
plt.hist(x)
plt.show()

# %%
# Grafico de Pastel
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()
